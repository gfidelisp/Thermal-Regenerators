# %% [markdown]
# # Deep Learning in Active Magnetic Regenerators

# %% [markdown]
# This Notebook presents the results for the application of Neural Networks in the prediction of the Cooling Capacity ($\dot{Q}_\mathrm{C}$ or $Qc$) and the Magnetization Power ($\dot{W}_\mathrm{m}$ or $Wm$) of Active Magnetic Regenerators. The Dataset consists in 532 points coming from numerical simulations.

# %% [markdown]
# ### Importing the Modules

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pathlib

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt

from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

import joblib

tf.config.optimizer.set_jit(True)
mpl.style.use('default')
plt.rc('text',usetex = True)
plt.rc('font', family='serif',size = 12)
# Out:
# C:\Users\Guilherme\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Plotting Functions

# %%
def plot_results(y_train,y_pred_train,y_test,y_pred_test,Obj):
    
    plt.figure()
    plt.plot(y_train,y_pred_train,'.',markersize = 7,color = '#1f77b4', mfc='none', label = 'Training Set')
    plt.plot(y_test,y_pred_test,'x' ,markersize = 5, color = '#2ca02c', mfc='none',label = 'Test Set',)
    
    if Obj == 'Qc [W]':
        Aux = np.linspace(0,80)
        plt.plot(Aux,0.95*Aux,'k--')
        plt.plot(Aux,1.05*Aux,'k--')
        #plt.text(140, 180, '$+ 5 \%$', fontsize=12)
        #plt.text(150, 120, '$- 5 \%$', fontsize=12)
        plt.legend()
        plt.ylabel(r' $\dot{Q}_\mathrm{C}$ [W] - ANN' )
        plt.xlabel(r' $\dot{Q}_\mathrm{C}$ [W] - Numerical Solution')
        plt.grid(linestyle='dotted')
        plt.savefig('Plots/Qc/Qc - NN.png', format = 'png', bbox_inches='tight') 
    
    elif Obj == 'Wm':
        Aux = np.linspace(10,60)
        plt.plot(Aux,0.95*Aux,'k--')
        plt.plot(Aux,1.05*Aux,'k--')
        plt.text(23, 17, '$- 5 \%$', fontsize=12)
        plt.text(19, 28, '$+ 5 \%$', fontsize=12)
        plt.legend()
        plt.ylabel(r' $\dot{W}_\mathrm{AMR,mag}$ [W] - ANN' )
        plt.xlabel(r' $\dot{W}_\mathrm{AMR,mag}$ [W] - Numerical Solution')
        plt.grid(linestyle='dotted')
        plt.savefig('Plots/Wm/Wm - NN.png', format = 'png', bbox_inches='tight')

# %% [markdown]
# ### Reading the Input Parameteres

# %% [markdown]
# The independent variable are the Width ($H$), Height ($H$) and Length ($L$) of the porous medium, the frequency ($f$) and mass flow rate ($mf$) of the Active Magnetic Regenerator, the Inlet Temperatures at the Hot ($Th$) and Cold ($Tc$) ends and the Applied Magnetic Field ($B$).
#
# The dependent variables are the Cooling Capacity ($Qc$) and Magnetization Power ($Wm$).

# %%
Inputs = pd.read_excel('Data/Data_AMR_Exp.xlsx',index_col = 0) # Input Data
X = Inputs[Inputs.columns[:-4]]
y = Inputs[['Qc [W]']]

# %% [markdown]
# ### Train-Test Split

# %%
Qc_min = 5

# %%
X = X[(y['Qc [W]'] > Qc_min) & (X['Test'] != 'MCR')]
y = y[(y['Qc [W]'] > Qc_min) & (X['Test'] != 'MCR')]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    test_size = 0.2,
                                                    stratify = X['Test'],
                                                    random_state = 42)
X_train = X_train.drop(['Test'],axis = 1)
X_test = X_test.drop(['Test'],axis = 1)

# %% [markdown]
# ### Scaling the Features

# %%
sc = joblib.load('Models/AMR_Scaler.pkl')
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# %%
joblib.dump(sc, 'Models/AMR_Scaler.pkl')
# Out:
# ['Models/AMR_Scaler.pkl']

# %% [markdown]
# ### Building the Model

# %%
def Build(hp):
    
    #Grouping a stack of Layers in Model
    model = tf.keras.Sequential()
    model.add(BatchNormalization())
    # Adding the Layers
    # The number of layers, neurons in each one and activation functions are going to be tunned 
    for i in range(hp.Int('layers', 0, 4)):
        model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i), 1, 1001, step=5),
                                        activation=hp.Choice('act_' + str(i), ['relu','sigmoid','selu'])))
        #model.add(Dropout(0.2))
        #Applying a Batch Normalization Layer after Dense Layer
        model.add(BatchNormalization())

        
    # Adding a final Layer 
    model.add(tf.keras.layers.Dense(1, activation='selu'))
    
    #model = tfmot.quantization.keras.quantize_model(model)
    # Compiling the Model with the Adam optimization algorithm
    model.compile(optimizer=Adam(),
                            loss="mean_squared_error",
                            #metrics=['accuracy']
                            metrics = ['accuracy']
                            )
    return model

# %% [markdown]
# ### Batch Optimization

# %% [markdown]
# Overriding run_trial in MyTuner (https://kegui.medium.com/how-to-tune-the-number-of-epochs-and-batch-size-in-keras-tuner-c2ab2d40878d)

# %%
class MyTuner(kt.Hyperband):
    def run_trial(self, trial, *args, **kwargs):
        kwargs['batch_size'] = trial.hyperparameters.Int('batch_size', 1, 501, step=5)
        super(MyTuner, self).run_trial(trial, *args, **kwargs)

# %% [markdown]
# ### Defining the Tuner

# %%
def NeuNet(X_train,y_train,max_epochs,Obj):
    
    # Defining the Tuner
    tuner = MyTuner(Build,
                    objective = 'val_loss',
                    max_epochs = max_epochs,
                    directory='KT_Dir',
                    project_name='KT_Hyperband_' + Obj,
                    executions_per_trial = 1,   
    )
    
    # Hyperparameter Optimization
    tuner.search(X_train,
                 y_train[Obj],
                 epochs=max_epochs,
                 #callbacks=[EarlyStopping('val_loss', patience=5)],
                 verbose=1,
                 validation_split=0.2)
    
  
    # Trainning the Best Model
    best_model = tuner.get_best_models()[0]
    best_model.build(X_train.shape)
    best_model.fit(X_train,
                   y_train[Obj], 
                   epochs=max_epochs,
                   batch_size=tuner.get_best_hyperparameters(num_trials=1)[0].get('batch_size')
    )
    best_model.summary()
    
    # Saving the Model
    best_model.save('Models/'+Obj+'/'+ Obj +'_NN.h5', include_optimizer=False)
    best_model.save('Models/'+Obj+'/'+ Obj +'_NN', include_optimizer=False)
    best_model.save_weights('Models/'+Obj+'/'+ Obj +'_weights.h5')
    #joblib.dump(best_model, 'Models/'+Obj+'/'+ Obj +'_NN.pkl')
    
     #R2 for the Training Set
    print('The coefficient of determination for '+ Obj +' Training Set using Neural Networks is '+
          str(r2_score(y_train[Obj], best_model.predict(X_train))))

    # R2 for the Test Set
    print('The coefficient of determination for '+ Obj +' Test Set using Neural Networks is '+
          str(r2_score(y_test[Obj], best_model.predict(X_test)))) 

    # Plotting the Results
    plot_results(y_train[Obj], best_model.predict(X_train), y_test[Obj], best_model.predict(X_test), Obj)

# %% [markdown]
# ### Defining a Test Function

# %%
def Test(X_train,y_train,Obj, Scal):
    
    Model = load_model('Models/'+Obj+'/'+ Obj +'_NN.h5', compile = False)
    Model.summary()
    Model.summary()
    for i, layer in enumerate (Model.layers):
        print (i, layer)
        try:
            print ("    ",layer.activation)
        except AttributeError:
            print('   no activation attribute')
            
    #R2 for the Training Set
    print('The coefficient of determination for '+ Obj +' Training Set using Neural Networks is '+
          str(r2_score(y_train[Obj], Model.predict(Scal.transform(X_train)))))

    # R2 for the Test Set
    print('The coefficient of determination for '+ Obj +' Test Set using Neural Networks is '+
          str(r2_score(y_test[Obj], Model.predict(Scal.transform(X_test))))) 

    # Plotting the Results
    plot_results(y_train[Obj], Model.predict(Scal.transform(X_train)), y_test[Obj], Model.predict(Scal.transform(X_test)), Obj)

# %%
def Test_lite(X_train,y_train,Obj, Scal):
    
    Model = load_model('Models/'+Obj+'/'+ Obj +'_NN.h5', compile = False)
    Model.summary()
    for i, layer in enumerate (Model.layers):
        print (i, layer)
        try:
            print ("    ",layer.activation)
        except AttributeError:
            print('   no activation attribute')
    converter = tf.lite.TFLiteConverter.from_keras_model(Model)
    tflite_model = converter.convert()
    tflite_models_dir = pathlib.Path("/")
    tflite_models_dir.mkdir(exist_ok=True, parents=True)
    tflite_model_file = tflite_models_dir/"mnist_model.tflite"
    tflite_model_file.write_bytes(tflite_model)
    
    interpreter = tf.lite.Interpreter(model_path=str(tflite_model_file))
    interpreter.allocate_tensors()
    
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    
    Train_Lite = []
    for i in range(np.shape(X_train)[0]):
        interpreter.set_tensor(input_index, Scaller.transform(X_train)[i].reshape(-1,1).T)
        interpreter.invoke()
        Train_Lite.append(interpreter.get_tensor(output_index)[0][0])
        
    Test_Lite = []
    for i in range(np.shape(X_test)[0]):
        interpreter.set_tensor(input_index, Scaller.transform(X_test)[i].reshape(-1,1).T)
        interpreter.invoke()
        Test_Lite.append(interpreter.get_tensor(output_index)[0][0])
    
    #R2 for the Training Set
    print('The coefficient of determination for '+ Obj +' Training Set using Neural Networks is '+
          str(r2_score(y_train[Obj], Train_Lite)))

    # R2 for the Test Set
    print('The coefficient of determination for '+ Obj +' Test Set using Neural Networks is '+
          str(r2_score(y_test[Obj], Test_Lite)))    
    
    # Plotting the Results
    plot_results(y_train[Obj], Train_Lite, y_test[Obj], Test_Lite, Obj)

# %% [markdown]
# ### Training the Models

# %%
NeuNet(X_train,y_train,1000,'Qc [W]')
# Out:
# Trial 2074 Complete [00h 00m 57s]
# val_loss: 32.53709030151367
#
# Best val_loss So Far: 12.433295249938965
# Total elapsed time: 02h 45m 19s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/1000
# 14/14 [==============================] - 1s 12ms/step - loss: 18.1711 - accuracy: 0.0000e+00
# Epoch 2/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.8051 - accuracy: 0.0000e+00
# Epoch 3/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9791 - accuracy: 0.0000e+00
# Epoch 4/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.4267 - accuracy: 0.0000e+00
# Epoch 5/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.2675 - accuracy: 0.0000e+00
# Epoch 6/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 36.2651 - accuracy: 0.0000e+00
# Epoch 7/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 27.1740 - accuracy: 0.0000e+00
# Epoch 8/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 23.0973 - accuracy: 0.0000e+00
# Epoch 9/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.9383 - accuracy: 0.0000e+00
# Epoch 10/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.8624 - accuracy: 0.0000e+00
# Epoch 11/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.7520 - accuracy: 0.0000e+00
# Epoch 12/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.3414 - accuracy: 0.0000e+00
# Epoch 13/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 26.8341 - accuracy: 0.0000e+00
# Epoch 14/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.4576 - accuracy: 0.0000e+00
# Epoch 15/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0024 - accuracy: 0.0000e+00
# Epoch 16/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.2813 - accuracy: 0.0000e+00
# Epoch 17/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.6883 - accuracy: 0.0000e+00
# Epoch 18/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.5158 - accuracy: 0.0000e+00
# Epoch 19/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 26.5630 - accuracy: 0.0000e+00
# Epoch 20/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.2096 - accuracy: 0.0000e+00
# Epoch 21/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 26.8076 - accuracy: 0.0000e+00
# Epoch 22/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.3144 - accuracy: 0.0000e+00
# Epoch 23/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.4677 - accuracy: 0.0000e+00
# Epoch 24/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.6456 - accuracy: 0.0000e+00
# Epoch 25/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.6810 - accuracy: 0.0000e+00
# Epoch 26/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.7185 - accuracy: 0.0000e+00
# Epoch 27/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.0333 - accuracy: 0.0000e+00
# Epoch 28/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.4462 - accuracy: 0.0000e+00
# Epoch 29/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.9937 - accuracy: 0.0000e+00
# Epoch 30/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.6093 - accuracy: 0.0000e+00
# Epoch 31/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 21.5756 - accuracy: 0.0000e+00
# Epoch 32/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.6053 - accuracy: 0.0000e+00
# Epoch 33/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 30.4821 - accuracy: 0.0000e+00
# Epoch 34/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 21.6093 - accuracy: 0.0000e+00
# Epoch 35/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.1612 - accuracy: 0.0000e+00
# Epoch 36/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.6948 - accuracy: 0.0000e+00
# Epoch 37/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.5824 - accuracy: 0.0000e+00
# Epoch 38/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.0648 - accuracy: 0.0000e+00
# Epoch 39/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.4826 - accuracy: 0.0000e+00
# Epoch 40/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.8853 - accuracy: 0.0000e+00
# Epoch 41/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.4287 - accuracy: 0.0000e+00
# Epoch 42/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.4390 - accuracy: 0.0000e+00
# Epoch 43/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1142 - accuracy: 0.0000e+00
# Epoch 44/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.5333 - accuracy: 0.0000e+00
# Epoch 45/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.9889 - accuracy: 0.0000e+00
# Epoch 46/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.7417 - accuracy: 0.0000e+00
# Epoch 47/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.0097 - accuracy: 0.0000e+00
# Epoch 48/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 22.9462 - accuracy: 0.0000e+00
# Epoch 49/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.5413 - accuracy: 0.0000e+00
# Epoch 50/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5127 - accuracy: 0.0000e+00
# Epoch 51/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5130 - accuracy: 0.0000e+00
# Epoch 52/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.5854 - accuracy: 0.0000e+00
# Epoch 53/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.3922 - accuracy: 0.0000e+00
# Epoch 54/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.8405 - accuracy: 0.0000e+00
# Epoch 55/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.0845 - accuracy: 0.0000e+00
# Epoch 56/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.5337 - accuracy: 0.0000e+00
# Epoch 57/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 27.3828 - accuracy: 0.0000e+00
# Epoch 58/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.9080 - accuracy: 0.0000e+00
# Epoch 59/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.5902 - accuracy: 0.0000e+00
# Epoch 60/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 12.9039 - accuracy: 0.0000e+00
# Epoch 61/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.2996 - accuracy: 0.0000e+00
# Epoch 62/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5191 - accuracy: 0.0000e+00
# Epoch 63/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.6298 - accuracy: 0.0000e+00
# Epoch 64/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.6414 - accuracy: 0.0000e+00
# Epoch 65/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.6318 - accuracy: 0.0000e+00
# Epoch 66/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 18.9989 - accuracy: 0.0000e+00
# Epoch 67/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.2130 - accuracy: 0.0000e+00
# Epoch 68/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.9489 - accuracy: 0.0000e+00
# Epoch 69/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.5965 - accuracy: 0.0000e+00
# Epoch 70/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.7876 - accuracy: 0.0000e+00
# Epoch 71/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.7465 - accuracy: 0.0000e+00
# Epoch 72/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.4205 - accuracy: 0.0000e+00
# Epoch 73/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.1221 - accuracy: 0.0000e+00
# Epoch 74/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.9269 - accuracy: 0.0000e+00
# Epoch 75/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.9976 - accuracy: 0.0000e+00
# Epoch 76/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.3121 - accuracy: 0.0000e+00
# Epoch 77/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.7624 - accuracy: 0.0000e+00
# Epoch 78/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.9623 - accuracy: 0.0000e+00
# Epoch 79/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.7626 - accuracy: 0.0000e+00
# Epoch 80/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.9321 - accuracy: 0.0000e+00
# Epoch 81/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.6267 - accuracy: 0.0000e+00
# Epoch 82/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.7610 - accuracy: 0.0000e+00
# Epoch 83/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 25.4864 - accuracy: 0.0000e+00
# Epoch 84/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.0425 - accuracy: 0.0000e+00
# Epoch 85/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 15.4898 - accuracy: 0.0000e+00
# Epoch 86/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.3171 - accuracy: 0.0000e+00
# Epoch 87/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.9680 - accuracy: 0.0000e+00
# Epoch 88/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0026 - accuracy: 0.0000e+00
# Epoch 89/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.1925 - accuracy: 0.0000e+00
# Epoch 90/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.2453 - accuracy: 0.0000e+00
# Epoch 91/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.2980 - accuracy: 0.0000e+00
# Epoch 92/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9943 - accuracy: 0.0000e+00
# Epoch 93/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.2578 - accuracy: 0.0000e+00
# Epoch 94/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5062 - accuracy: 0.0000e+00
# Epoch 95/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.2644 - accuracy: 0.0000e+00
# Epoch 96/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.2794 - accuracy: 0.0000e+00
# Epoch 97/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 18.0529 - accuracy: 0.0000e+00
# Epoch 98/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.2384 - accuracy: 0.0000e+00
# Epoch 99/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.0961 - accuracy: 0.0000e+00
# Epoch 100/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.2604 - accuracy: 0.0000e+00
# Epoch 101/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 16.7676 - accuracy: 0.0000e+00
# Epoch 102/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.5431 - accuracy: 0.0000e+00
# Epoch 103/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 30.8766 - accuracy: 0.0000e+00
# Epoch 104/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.8500 - accuracy: 0.0000e+00
# Epoch 105/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0604 - accuracy: 0.0000e+00
# Epoch 106/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.0048 - accuracy: 0.0000e+00
# Epoch 107/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.5470 - accuracy: 0.0000e+00
# Epoch 108/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.7591 - accuracy: 0.0000e+00
# Epoch 109/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.0380 - accuracy: 0.0000e+00
# Epoch 110/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.3563 - accuracy: 0.0000e+00
# Epoch 111/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.8617 - accuracy: 0.0000e+00
# Epoch 112/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.1575 - accuracy: 0.0000e+00
# Epoch 113/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.8668 - accuracy: 0.0000e+00
# Epoch 114/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.9243 - accuracy: 0.0000e+00
# Epoch 115/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.2262 - accuracy: 0.0000e+00
# Epoch 116/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.3739 - accuracy: 0.0000e+00
# Epoch 117/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.3886 - accuracy: 0.0000e+00
# Epoch 118/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.7334 - accuracy: 0.0000e+00
# Epoch 119/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.3864 - accuracy: 0.0000e+00
# Epoch 120/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.2650 - accuracy: 0.0000e+00
# Epoch 121/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.7176 - accuracy: 0.0000e+00
# Epoch 122/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 23.5067 - accuracy: 0.0000e+00
# Epoch 123/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.4251 - accuracy: 0.0000e+00
# Epoch 124/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.0657 - accuracy: 0.0000e+00
# Epoch 125/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 15.9837 - accuracy: 0.0000e+00
# Epoch 126/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 23.6605 - accuracy: 0.0000e+00
# Epoch 127/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.4516 - accuracy: 0.0000e+00
# Epoch 128/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.8485 - accuracy: 0.0000e+00
# Epoch 129/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.7236 - accuracy: 0.0000e+00
# Epoch 130/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.4910 - accuracy: 0.0000e+00
# Epoch 131/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 15.3023 - accuracy: 0.0000e+00
# Epoch 132/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.6978 - accuracy: 0.0000e+00
# Epoch 133/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.6223 - accuracy: 0.0000e+00
# Epoch 134/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5996 - accuracy: 0.0000e+00
# Epoch 135/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.0197 - accuracy: 0.0000e+00
# Epoch 136/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0672 - accuracy: 0.0000e+00
# Epoch 137/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 18.4783 - accuracy: 0.0000e+00
# Epoch 138/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.5059 - accuracy: 0.0000e+00
# Epoch 139/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1120 - accuracy: 0.0000e+00
# Epoch 140/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.1830 - accuracy: 0.0000e+00
# Epoch 141/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.7493 - accuracy: 0.0000e+00
# Epoch 142/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.9125 - accuracy: 0.0000e+00
# Epoch 143/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.1136 - accuracy: 0.0000e+00
# Epoch 144/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.6558 - accuracy: 0.0000e+00
# Epoch 145/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.1106 - accuracy: 0.0000e+00
# Epoch 146/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.9759 - accuracy: 0.0000e+00
# Epoch 147/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.5441 - accuracy: 0.0000e+00
# Epoch 148/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 25.0722 - accuracy: 0.0000e+00
# Epoch 149/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 17.9546 - accuracy: 0.0000e+00
# Epoch 150/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.9775 - accuracy: 0.0000e+00
# Epoch 151/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.8636 - accuracy: 0.0000e+00
# Epoch 152/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.8129 - accuracy: 0.0000e+00
# Epoch 153/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.3636 - accuracy: 0.0000e+00
# Epoch 154/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 16.1172 - accuracy: 0.0000e+00
# Epoch 155/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.2705 - accuracy: 0.0000e+00
# Epoch 156/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.3809 - accuracy: 0.0000e+00
# Epoch 157/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.7696 - accuracy: 0.0000e+00
# Epoch 158/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.3451 - accuracy: 0.0000e+00
# Epoch 159/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.8329 - accuracy: 0.0000e+00
# Epoch 160/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9836 - accuracy: 0.0000e+00
# Epoch 161/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.4139 - accuracy: 0.0000e+00
# Epoch 162/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.4763 - accuracy: 0.0000e+00
# Epoch 163/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.2763 - accuracy: 0.0000e+00
# Epoch 164/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.9430 - accuracy: 0.0000e+00
# Epoch 165/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.4566 - accuracy: 0.0000e+00
# Epoch 166/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 17.1318 - accuracy: 0.0000e+00
# Epoch 167/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.5830 - accuracy: 0.0000e+00
# Epoch 168/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5268 - accuracy: 0.0000e+00
# Epoch 169/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.3593 - accuracy: 0.0000e+00
# Epoch 170/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.2334 - accuracy: 0.0000e+00
# Epoch 171/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.1719 - accuracy: 0.0000e+00
# Epoch 172/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.2507 - accuracy: 0.0000e+00
# Epoch 173/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.5609 - accuracy: 0.0000e+00
# Epoch 174/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.5288 - accuracy: 0.0000e+00
# Epoch 175/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.8438 - accuracy: 0.0000e+00
# Epoch 176/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5433 - accuracy: 0.0000e+00
# Epoch 177/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.6938 - accuracy: 0.0000e+00
# Epoch 178/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.3915 - accuracy: 0.0000e+00
# Epoch 179/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.7288 - accuracy: 0.0000e+00
# Epoch 180/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1664 - accuracy: 0.0000e+00
# Epoch 181/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.6637 - accuracy: 0.0000e+00
# Epoch 182/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.3100 - accuracy: 0.0000e+00
# Epoch 183/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.3318 - accuracy: 0.0000e+00
# Epoch 184/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 20.2939 - accuracy: 0.0000e+00
# Epoch 185/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2999 - accuracy: 0.0000e+00
# Epoch 186/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.1376 - accuracy: 0.0000e+00
# Epoch 187/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1390 - accuracy: 0.0000e+00
# Epoch 188/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.4286 - accuracy: 0.0000e+00
# Epoch 189/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.8929 - accuracy: 0.0000e+00
# Epoch 190/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 24.1881 - accuracy: 0.0000e+00
# Epoch 191/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.8778 - accuracy: 0.0000e+00
# Epoch 192/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.3978 - accuracy: 0.0000e+00
# Epoch 193/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.1870 - accuracy: 0.0000e+00
# Epoch 194/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.3083 - accuracy: 0.0000e+00
# Epoch 195/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9308 - accuracy: 0.0000e+00
# Epoch 196/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.6407 - accuracy: 0.0000e+00
# Epoch 197/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3861 - accuracy: 0.0000e+00
# Epoch 198/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.0192 - accuracy: 0.0000e+00
# Epoch 199/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.0542 - accuracy: 0.0000e+00
# Epoch 200/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 24.2930 - accuracy: 0.0000e+00
# Epoch 201/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 14.8564 - accuracy: 0.0000e+00
# Epoch 202/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 23.9194 - accuracy: 0.0000e+00
# Epoch 203/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9181 - accuracy: 0.0000e+00
# Epoch 204/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.8033 - accuracy: 0.0000e+00
# Epoch 205/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.3299 - accuracy: 0.0000e+00
# Epoch 206/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.4168 - accuracy: 0.0000e+00
# Epoch 207/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 12.9587 - accuracy: 0.0000e+00
# Epoch 208/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1986 - accuracy: 0.0000e+00
# Epoch 209/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.6152 - accuracy: 0.0000e+00
# Epoch 210/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.4568 - accuracy: 0.0000e+00
# Epoch 211/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.7050 - accuracy: 0.0000e+00
# Epoch 212/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.7684 - accuracy: 0.0000e+00
# Epoch 213/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.4530 - accuracy: 0.0000e+00
# Epoch 214/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 21.9159 - accuracy: 0.0000e+00
# Epoch 215/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1522 - accuracy: 0.0000e+00
# Epoch 216/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.9975 - accuracy: 0.0000e+00
# Epoch 217/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.1280 - accuracy: 0.0000e+00
# Epoch 218/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.8833 - accuracy: 0.0000e+00
# Epoch 219/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.7027 - accuracy: 0.0000e+00
# Epoch 220/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.7450 - accuracy: 0.0000e+00
# Epoch 221/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.6123 - accuracy: 0.0000e+00
# Epoch 222/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 17.2329 - accuracy: 0.0000e+00
# Epoch 223/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.2224 - accuracy: 0.0000e+00
# Epoch 224/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5301 - accuracy: 0.0000e+00
# Epoch 225/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5527 - accuracy: 0.0000e+00
# Epoch 226/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.3212 - accuracy: 0.0000e+00
# Epoch 227/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.2315 - accuracy: 0.0000e+00
# Epoch 228/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0365 - accuracy: 0.0000e+00
# Epoch 229/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1329 - accuracy: 0.0000e+00
# Epoch 230/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.1494 - accuracy: 0.0000e+00
# Epoch 231/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 16.6368 - accuracy: 0.0000e+00
# Epoch 232/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 26.3802 - accuracy: 0.0000e+00
# Epoch 233/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.7633 - accuracy: 0.0000e+00
# Epoch 234/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.4839 - accuracy: 0.0000e+00
# Epoch 235/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5547 - accuracy: 0.0000e+00
# Epoch 236/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.7533 - accuracy: 0.0000e+00
# Epoch 237/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.0085 - accuracy: 0.0000e+00
# Epoch 238/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.1587 - accuracy: 0.0000e+00
# Epoch 239/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2141 - accuracy: 0.0000e+00
# Epoch 240/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.0857 - accuracy: 0.0000e+00
# Epoch 241/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.3878 - accuracy: 0.0000e+00
# Epoch 242/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.9124 - accuracy: 0.0000e+00
# Epoch 243/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 20.3551 - accuracy: 0.0000e+00
# Epoch 244/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.3728 - accuracy: 0.0000e+00
# Epoch 245/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.9783 - accuracy: 0.0000e+00
# Epoch 246/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.3060 - accuracy: 0.0000e+00
# Epoch 247/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.8839 - accuracy: 0.0000e+00
# Epoch 248/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.8557 - accuracy: 0.0000e+00
# Epoch 249/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.9375 - accuracy: 0.0000e+00
# Epoch 250/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 28.0982 - accuracy: 0.0000e+00
# Epoch 251/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.8616 - accuracy: 0.0000e+00
# Epoch 252/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.3181 - accuracy: 0.0000e+00
# Epoch 253/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.6090 - accuracy: 0.0000e+00
# Epoch 254/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5457 - accuracy: 0.0000e+00
# Epoch 255/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.1667 - accuracy: 0.0000e+00
# Epoch 256/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.7308 - accuracy: 0.0000e+00
# Epoch 257/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.4370 - accuracy: 0.0000e+00
# Epoch 258/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 11.8793 - accuracy: 0.0000e+00
# Epoch 259/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.0215 - accuracy: 0.0000e+00
# Epoch 260/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 24.9987 - accuracy: 0.0000e+00
# Epoch 261/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.7280 - accuracy: 0.0000e+00
# Epoch 262/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.1935 - accuracy: 0.0000e+00
# Epoch 263/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.1014 - accuracy: 0.0000e+00
# Epoch 264/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5823 - accuracy: 0.0000e+00
# Epoch 265/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 11.4275 - accuracy: 0.0000e+00
# Epoch 266/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 13.3064 - accuracy: 0.0000e+00
# Epoch 267/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.9716 - accuracy: 0.0000e+00
# Epoch 268/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3237 - accuracy: 0.0000e+00
# Epoch 269/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.0289 - accuracy: 0.0000e+00
# Epoch 270/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.5308 - accuracy: 0.0000e+00
# Epoch 271/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.3823 - accuracy: 0.0000e+00
# Epoch 272/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 17.4585 - accuracy: 0.0000e+00
# Epoch 273/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5838 - accuracy: 0.0000e+00
# Epoch 274/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.7667 - accuracy: 0.0000e+00
# Epoch 275/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.0281 - accuracy: 0.0000e+00
# Epoch 276/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.8155 - accuracy: 0.0000e+00
# Epoch 277/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.5132 - accuracy: 0.0000e+00
# Epoch 278/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.8517 - accuracy: 0.0000e+00
# Epoch 279/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.6303 - accuracy: 0.0000e+00
# Epoch 280/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.5711 - accuracy: 0.0000e+00
# Epoch 281/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.2051 - accuracy: 0.0000e+00
# Epoch 282/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.3957 - accuracy: 0.0000e+00
# Epoch 283/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.6870 - accuracy: 0.0000e+00
# Epoch 284/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1733 - accuracy: 0.0000e+00
# Epoch 285/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.4121 - accuracy: 0.0000e+00
# Epoch 286/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.9229 - accuracy: 0.0000e+00
# Epoch 287/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.3416 - accuracy: 0.0000e+00
# Epoch 288/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 23.5030 - accuracy: 0.0000e+00
# Epoch 289/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.1794 - accuracy: 0.0000e+00
# Epoch 290/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0128 - accuracy: 0.0000e+00
# Epoch 291/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.9671 - accuracy: 0.0000e+00
# Epoch 292/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 12.7569 - accuracy: 0.0000e+00
# Epoch 293/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 17.1841 - accuracy: 0.0000e+00
# Epoch 294/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.6625 - accuracy: 0.0000e+00
# Epoch 295/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.8113 - accuracy: 0.0000e+00
# Epoch 296/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.0031 - accuracy: 0.0000e+00
# Epoch 297/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.6396 - accuracy: 0.0000e+00
# Epoch 298/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.0560 - accuracy: 0.0000e+00
# Epoch 299/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.6069 - accuracy: 0.0000e+00
# Epoch 300/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.1461 - accuracy: 0.0000e+00
# Epoch 301/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9558 - accuracy: 0.0000e+00
# Epoch 302/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.0645 - accuracy: 0.0000e+00
# Epoch 303/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.3197 - accuracy: 0.0000e+00
# Epoch 304/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2853 - accuracy: 0.0000e+00
# Epoch 305/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3208 - accuracy: 0.0000e+00
# Epoch 306/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.5402 - accuracy: 0.0000e+00
# Epoch 307/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.9035 - accuracy: 0.0000e+00
# Epoch 308/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 13.4286 - accuracy: 0.0000e+00
# Epoch 309/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.1140 - accuracy: 0.0000e+00
# Epoch 310/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.1935 - accuracy: 0.0000e+00
# Epoch 311/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1172 - accuracy: 0.0000e+00
# Epoch 312/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.4203 - accuracy: 0.0000e+00
# Epoch 313/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.6820 - accuracy: 0.0000e+00
# Epoch 314/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5994 - accuracy: 0.0000e+00
# Epoch 315/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.5573 - accuracy: 0.0000e+00
# Epoch 316/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.5722 - accuracy: 0.0000e+00
# Epoch 317/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.9233 - accuracy: 0.0000e+00
# Epoch 318/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.2566 - accuracy: 0.0000e+00
# Epoch 319/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.7592 - accuracy: 0.0000e+00
# Epoch 320/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 17.8935 - accuracy: 0.0000e+00
# Epoch 321/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.4570 - accuracy: 0.0000e+00
# Epoch 322/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.4255 - accuracy: 0.0000e+00
# Epoch 323/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.8981 - accuracy: 0.0000e+00
# Epoch 324/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.9387 - accuracy: 0.0000e+00
# Epoch 325/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.7651 - accuracy: 0.0000e+00
# Epoch 326/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.1579 - accuracy: 0.0000e+00
# Epoch 327/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5880 - accuracy: 0.0000e+00
# Epoch 328/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.6605 - accuracy: 0.0000e+00
# Epoch 329/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.6483 - accuracy: 0.0000e+00
# Epoch 330/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.8703 - accuracy: 0.0000e+00
# Epoch 331/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.6423 - accuracy: 0.0000e+00
# Epoch 332/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.3452 - accuracy: 0.0000e+00
# Epoch 333/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.9558 - accuracy: 0.0000e+00
# Epoch 334/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.5630 - accuracy: 0.0000e+00
# Epoch 335/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.4528 - accuracy: 0.0000e+00
# Epoch 336/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 18.4588 - accuracy: 0.0000e+00
# Epoch 337/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.6239 - accuracy: 0.0000e+00
# Epoch 338/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.6658 - accuracy: 0.0000e+00
# Epoch 339/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.8029 - accuracy: 0.0000e+00
# Epoch 340/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.3920 - accuracy: 0.0000e+00
# Epoch 341/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5118 - accuracy: 0.0000e+00
# Epoch 342/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 14.8610 - accuracy: 0.0000e+00
# Epoch 343/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2398 - accuracy: 0.0000e+00
# Epoch 344/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 15.4014 - accuracy: 0.0000e+00
# Epoch 345/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.4084 - accuracy: 0.0000e+00
# Epoch 346/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 23.3043 - accuracy: 0.0000e+00
# Epoch 347/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.7986 - accuracy: 0.0000e+00
# Epoch 348/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.9346 - accuracy: 0.0000e+00
# Epoch 349/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.3004 - accuracy: 0.0000e+00
# Epoch 350/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.9260 - accuracy: 0.0000e+00
# Epoch 351/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 19.9274 - accuracy: 0.0000e+00
# Epoch 352/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.9484 - accuracy: 0.0000e+00
# Epoch 353/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.0016 - accuracy: 0.0000e+00
# Epoch 354/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 15.6412 - accuracy: 0.0000e+00
# Epoch 355/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.8758 - accuracy: 0.0000e+00
# Epoch 356/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.8539 - accuracy: 0.0000e+00
# Epoch 357/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.4975 - accuracy: 0.0000e+00
# Epoch 358/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 16.8653 - accuracy: 0.0000e+00
# Epoch 359/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 19.8443 - accuracy: 0.0000e+00
# Epoch 360/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.0239 - accuracy: 0.0000e+00
# Epoch 361/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.7144 - accuracy: 0.0000e+00
# Epoch 362/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.8818 - accuracy: 0.0000e+00
# Epoch 363/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0449 - accuracy: 0.0000e+00
# Epoch 364/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2710 - accuracy: 0.0000e+00
# Epoch 365/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5282 - accuracy: 0.0000e+00
# Epoch 366/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.4783 - accuracy: 0.0000e+00
# Epoch 367/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1696 - accuracy: 0.0000e+00
# Epoch 368/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.8104 - accuracy: 0.0000e+00
# Epoch 369/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.9898 - accuracy: 0.0000e+00
# Epoch 370/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.3988 - accuracy: 0.0000e+00
# Epoch 371/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.8476 - accuracy: 0.0000e+00
# Epoch 372/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.7698 - accuracy: 0.0000e+00
# Epoch 373/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5820 - accuracy: 0.0000e+00
# Epoch 374/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.1333 - accuracy: 0.0000e+00
# Epoch 375/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.8138 - accuracy: 0.0000e+00
# Epoch 376/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.7613 - accuracy: 0.0000e+00
# Epoch 377/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.6689 - accuracy: 0.0000e+00
# Epoch 378/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.6477 - accuracy: 0.0000e+00
# Epoch 379/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.2967 - accuracy: 0.0000e+00
# Epoch 380/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 22.6494 - accuracy: 0.0000e+00
# Epoch 381/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.3993 - accuracy: 0.0000e+00
# Epoch 382/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.1798 - accuracy: 0.0000e+00
# Epoch 383/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.1386 - accuracy: 0.0000e+00
# Epoch 384/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5788 - accuracy: 0.0000e+00
# Epoch 385/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.7645 - accuracy: 0.0000e+00
# Epoch 386/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.4868 - accuracy: 0.0000e+00
# Epoch 387/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2952 - accuracy: 0.0000e+00
# Epoch 388/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.3609 - accuracy: 0.0000e+00
# Epoch 389/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.6466 - accuracy: 0.0000e+00
# Epoch 390/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.0851 - accuracy: 0.0000e+00
# Epoch 391/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.8369 - accuracy: 0.0000e+00
# Epoch 392/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5282 - accuracy: 0.0000e+00
# Epoch 393/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5125 - accuracy: 0.0000e+00
# Epoch 394/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.9879 - accuracy: 0.0000e+00
# Epoch 395/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1180 - accuracy: 0.0000e+00
# Epoch 396/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.3083 - accuracy: 0.0000e+00
# Epoch 397/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1293 - accuracy: 0.0000e+00
# Epoch 398/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.9213 - accuracy: 0.0000e+00
# Epoch 399/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.4501 - accuracy: 0.0000e+00
# Epoch 400/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9342 - accuracy: 0.0000e+00
# Epoch 401/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.5680 - accuracy: 0.0000e+00
# Epoch 402/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.0254 - accuracy: 0.0000e+00
# Epoch 403/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 13.0499 - accuracy: 0.0000e+00
# Epoch 404/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.3336 - accuracy: 0.0000e+00
# Epoch 405/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.4969 - accuracy: 0.0000e+00
# Epoch 406/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.0988 - accuracy: 0.0000e+00
# Epoch 407/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.5039 - accuracy: 0.0000e+00
# Epoch 408/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 13.2748 - accuracy: 0.0000e+00
# Epoch 409/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5833 - accuracy: 0.0000e+00
# Epoch 410/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2995 - accuracy: 0.0000e+00
# Epoch 411/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.6090 - accuracy: 0.0000e+00
# Epoch 412/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.6624 - accuracy: 0.0000e+00
# Epoch 413/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.4979 - accuracy: 0.0000e+00
# Epoch 414/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0304 - accuracy: 0.0000e+00
# Epoch 415/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.6602 - accuracy: 0.0000e+00
# Epoch 416/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.6413 - accuracy: 0.0000e+00
# Epoch 417/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.6596 - accuracy: 0.0000e+00
# Epoch 418/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.0999 - accuracy: 0.0000e+00
# Epoch 419/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.6164 - accuracy: 0.0000e+00
# Epoch 420/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.8255 - accuracy: 0.0000e+00
# Epoch 421/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.7023 - accuracy: 0.0000e+00
# Epoch 422/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3164 - accuracy: 0.0000e+00
# Epoch 423/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.6712 - accuracy: 0.0000e+00
# Epoch 424/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.5413 - accuracy: 0.0000e+00
# Epoch 425/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.9724 - accuracy: 0.0000e+00
# Epoch 426/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.3778 - accuracy: 0.0000e+00
# Epoch 427/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3165 - accuracy: 0.0000e+00
# Epoch 428/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5694 - accuracy: 0.0000e+00
# Epoch 429/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.9787 - accuracy: 0.0000e+00
# Epoch 430/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.5866 - accuracy: 0.0000e+00
# Epoch 431/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.0949 - accuracy: 0.0000e+00
# Epoch 432/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2562 - accuracy: 0.0000e+00
# Epoch 433/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.5631 - accuracy: 0.0000e+00
# Epoch 434/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.8095 - accuracy: 0.0000e+00
# Epoch 435/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.3409 - accuracy: 0.0000e+00
# Epoch 436/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.6893 - accuracy: 0.0000e+00
# Epoch 437/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.8650 - accuracy: 0.0000e+00
# Epoch 438/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.0392 - accuracy: 0.0000e+00
# Epoch 439/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5829 - accuracy: 0.0000e+00
# Epoch 440/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5272 - accuracy: 0.0000e+00
# Epoch 441/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.2662 - accuracy: 0.0000e+00
# Epoch 442/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 20.1231 - accuracy: 0.0000e+00
# Epoch 443/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.0344 - accuracy: 0.0000e+00
# Epoch 444/1000
# ...
# Epoch 877/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.4493 - accuracy: 0.0000e+00
# Epoch 878/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.6218 - accuracy: 0.0000e+00
# Epoch 879/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.4044 - accuracy: 0.0000e+00
# Epoch 880/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.0600 - accuracy: 0.0000e+00
# Epoch 881/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.9765 - accuracy: 0.0000e+00
# Epoch 882/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.5240 - accuracy: 0.0000e+00
# Epoch 883/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.7754 - accuracy: 0.0000e+00
# Epoch 884/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.7964 - accuracy: 0.0000e+00
# Epoch 885/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5337 - accuracy: 0.0000e+00
# Epoch 886/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.0735 - accuracy: 0.0000e+00
# Epoch 887/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9113 - accuracy: 0.0000e+00
# Epoch 888/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 13.3274 - accuracy: 0.0000e+00
# Epoch 889/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 11.5630 - accuracy: 0.0000e+00
# Epoch 890/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.0307 - accuracy: 0.0000e+00
# Epoch 891/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.1953 - accuracy: 0.0000e+00
# Epoch 892/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.5951 - accuracy: 0.0000e+00
# Epoch 893/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.7349 - accuracy: 0.0000e+00
# Epoch 894/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.1491 - accuracy: 0.0000e+00
# Epoch 895/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1388 - accuracy: 0.0000e+00
# Epoch 896/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 12.5902 - accuracy: 0.0000e+00
# Epoch 897/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.4006 - accuracy: 0.0000e+00
# Epoch 898/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.4846 - accuracy: 0.0000e+00
# Epoch 899/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.0428 - accuracy: 0.0000e+00
# Epoch 900/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.0367 - accuracy: 0.0000e+00
# Epoch 901/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.5783 - accuracy: 0.0000e+00
# Epoch 902/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.1843 - accuracy: 0.0000e+00
# Epoch 903/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.6753 - accuracy: 0.0000e+00
# Epoch 904/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 12.2740 - accuracy: 0.0000e+00
# Epoch 905/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1323 - accuracy: 0.0000e+00
# Epoch 906/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.6111 - accuracy: 0.0000e+00
# Epoch 907/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 13.5745 - accuracy: 0.0000e+00
# Epoch 908/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3689 - accuracy: 0.0000e+00
# Epoch 909/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.2589 - accuracy: 0.0000e+00
# Epoch 910/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.7152 - accuracy: 0.0000e+00
# Epoch 911/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.1096 - accuracy: 0.0000e+00
# Epoch 912/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.4599 - accuracy: 0.0000e+00
# Epoch 913/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 13.2924 - accuracy: 0.0000e+00
# Epoch 914/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 19.6201 - accuracy: 0.0000e+00
# Epoch 915/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.4880 - accuracy: 0.0000e+00
# Epoch 916/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.6636 - accuracy: 0.0000e+00
# Epoch 917/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 8.8765 - accuracy: 0.0000e+00
# Epoch 918/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.8103 - accuracy: 0.0000e+00
# Epoch 919/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.7764 - accuracy: 0.0000e+00
# Epoch 920/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.9528 - accuracy: 0.0000e+00
# Epoch 921/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.1834 - accuracy: 0.0000e+00
# Epoch 922/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.0776 - accuracy: 0.0000e+00
# Epoch 923/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.0690 - accuracy: 0.0000e+00
# Epoch 924/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 21.1877 - accuracy: 0.0000e+00
# Epoch 925/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.3553 - accuracy: 0.0000e+00
# Epoch 926/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.0480 - accuracy: 0.0000e+00
# Epoch 927/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.9574 - accuracy: 0.0000e+00
# Epoch 928/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.7989 - accuracy: 0.0000e+00
# Epoch 929/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.1620 - accuracy: 0.0000e+00
# Epoch 930/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5840 - accuracy: 0.0000e+00
# Epoch 931/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 17.5254 - accuracy: 0.0000e+00
# Epoch 932/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.5580 - accuracy: 0.0000e+00
# Epoch 933/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 9.8583 - accuracy: 0.0000e+00
# Epoch 934/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.9938 - accuracy: 0.0000e+00
# Epoch 935/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.7333 - accuracy: 0.0000e+00
# Epoch 936/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 9.8334 - accuracy: 0.0000e+00
# Epoch 937/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.7311 - accuracy: 0.0000e+00
# Epoch 938/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.7447 - accuracy: 0.0000e+00
# Epoch 939/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.2177 - accuracy: 0.0000e+00
# Epoch 940/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.0295 - accuracy: 0.0000e+00
# Epoch 941/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.1004 - accuracy: 0.0000e+00
# Epoch 942/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.1530 - accuracy: 0.0000e+00
# Epoch 943/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5551 - accuracy: 0.0000e+00
# Epoch 944/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 15.9614 - accuracy: 0.0000e+00
# Epoch 945/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.0816 - accuracy: 0.0000e+00
# Epoch 946/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.6643 - accuracy: 0.0000e+00
# Epoch 947/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 14.6683 - accuracy: 0.0000e+00
# Epoch 948/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 12.4513 - accuracy: 0.0000e+00
# Epoch 949/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.7794 - accuracy: 0.0000e+00
# Epoch 950/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 13.7871 - accuracy: 0.0000e+00
# Epoch 951/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.5821 - accuracy: 0.0000e+00
# Epoch 952/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.0992 - accuracy: 0.0000e+00
# Epoch 953/1000
# 14/14 [==============================] - 0s 13ms/step - loss: 12.9160 - accuracy: 0.0000e+00
# Epoch 954/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.9842 - accuracy: 0.0000e+00
# Epoch 955/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.1376 - accuracy: 0.0000e+00
# Epoch 956/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.0739 - accuracy: 0.0000e+00
# Epoch 957/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.2843 - accuracy: 0.0000e+00
# Epoch 958/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.0921 - accuracy: 0.0000e+00
# Epoch 959/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.5750 - accuracy: 0.0000e+00
# Epoch 960/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 11.2796 - accuracy: 0.0000e+00
# Epoch 961/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.5795 - accuracy: 0.0000e+00
# Epoch 962/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.9260 - accuracy: 0.0000e+00
# Epoch 963/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9482 - accuracy: 0.0000e+00
# Epoch 964/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.6992 - accuracy: 0.0000e+00
# Epoch 965/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.6247 - accuracy: 0.0000e+00
# Epoch 966/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 11.7398 - accuracy: 0.0000e+00
# Epoch 967/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 9.4762 - accuracy: 0.0000e+00
# Epoch 968/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.0544 - accuracy: 0.0000e+00
# Epoch 969/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.3557 - accuracy: 0.0000e+00
# Epoch 970/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2810 - accuracy: 0.0000e+00
# Epoch 971/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.5181 - accuracy: 0.0000e+00
# Epoch 972/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 12.9545 - accuracy: 0.0000e+00
# Epoch 973/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.7080 - accuracy: 0.0000e+00
# Epoch 974/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 15.7495 - accuracy: 0.0000e+00
# Epoch 975/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 17.9647 - accuracy: 0.0000e+00
# Epoch 976/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.5819 - accuracy: 0.0000e+00
# Epoch 977/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 18.0990 - accuracy: 0.0000e+00
# Epoch 978/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.1634 - accuracy: 0.0000e+00
# Epoch 979/1000
# 14/14 [==============================] - 0s 11ms/step - loss: 16.0130 - accuracy: 0.0000e+00
# Epoch 980/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.8834 - accuracy: 0.0000e+00
# Epoch 981/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3606 - accuracy: 0.0000e+00
# Epoch 982/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.8317 - accuracy: 0.0000e+00
# Epoch 983/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.2574 - accuracy: 0.0000e+00
# Epoch 984/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.7088 - accuracy: 0.0000e+00
# Epoch 985/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.1317 - accuracy: 0.0000e+00
# Epoch 986/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.7906 - accuracy: 0.0000e+00
# Epoch 987/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.8480 - accuracy: 0.0000e+00
# Epoch 988/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.3316 - accuracy: 0.0000e+00
# Epoch 989/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 16.5155 - accuracy: 0.0000e+00
# Epoch 990/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.9630 - accuracy: 0.0000e+00
# Epoch 991/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 11.4882 - accuracy: 0.0000e+00
# Epoch 992/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.6438 - accuracy: 0.0000e+00
# Epoch 993/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.4216 - accuracy: 0.0000e+00
# Epoch 994/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.1703 - accuracy: 0.0000e+00
# Epoch 995/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 13.3686 - accuracy: 0.0000e+00
# Epoch 996/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.7993 - accuracy: 0.0000e+00
# Epoch 997/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 12.5966 - accuracy: 0.0000e+00
# Epoch 998/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 23.6875 - accuracy: 0.0000e+00
# Epoch 999/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 14.1746 - accuracy: 0.0000e+00
# Epoch 1000/1000
# 14/14 [==============================] - 0s 12ms/step - loss: 10.7518 - accuracy: 0.0000e+00
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 31)               124
#  ormalization)
#
#  dense (Dense)               (None, 991)               31712
#
#  batch_normalization_1 (Batc  (None, 991)              3964
#  hNormalization)
#
#  dense_1 (Dense)             (None, 536)               531712
#
#  batch_normalization_2 (Batc  (None, 536)              2144
#  hNormalization)
#
#  dense_2 (Dense)             (None, 861)               462357
#
#  batch_normalization_3 (Batc  (None, 861)              3444
#  hNormalization)
#
#  dense_3 (Dense)             (None, 891)               768042
#
#  batch_normalization_4 (Batc  (None, 891)              3564
#  hNormalization)
#
#  dense_4 (Dense)             (None, 1)                 892
#
# =================================================================
# Total params: 1,807,955
# Trainable params: 1,801,335
# Non-trainable params: 6,620
# _________________________________________________________________
# INFO:tensorflow:Assets written to: Models/Qc [W]/Qc [W]_NN\assets
# 9/9 [==============================] - 0s 5ms/step
# The coefficient of determination for Qc [W] Training Set using Neural Networks is 0.9514053786587819
# 3/3 [==============================] - 0s 4ms/step
# The coefficient of determination for Qc [W] Test Set using Neural Networks is 0.9071609545592232
# 9/9 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step

# %% [markdown]
# ### Testing the Models

# %% [markdown]
# ### Reading the Input Parameteres

# %%
Inputs = pd.read_excel('Data/Data_AMR_Exp.xlsx',index_col = 0) # Input Data
X = Inputs[Inputs.columns[:-4]]
y = Inputs[['Qc [W]']]

# %% [markdown]
# ### Train-Test Split

# %%
X = X[(y['Qc [W]'] > Qc_min) & (X['Test'] != 'MCR')]
y = y[(y['Qc [W]'] > Qc_min) & (X['Test'] != 'MCR')]

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    test_size = 0.2,
                                                    stratify = X['Test'],
                                                    random_state = 42)
X_train = X_train.drop(['Test'],axis = 1)
X_test = X_test.drop(['Test'],axis = 1)

# %% [markdown]
# ### Scaling the Features

# %%
Scaller = joblib.load('Models/AMR_Scaler.pkl')

# %%
Test(X_train,y_train,'Qc [W]',Scaller)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 31)               124
#  ormalization)
#
#  dense (Dense)               (None, 991)               31712
#
#  batch_normalization_1 (Batc  (None, 991)              3964
#  hNormalization)
#
#  dense_1 (Dense)             (None, 536)               531712
#
#  batch_normalization_2 (Batc  (None, 536)              2144
#  hNormalization)
#
#  dense_2 (Dense)             (None, 861)               462357
#
#  batch_normalization_3 (Batc  (None, 861)              3444
#  hNormalization)
#
#  dense_3 (Dense)             (None, 891)               768042
#
#  batch_normalization_4 (Batc  (None, 891)              3564
#  hNormalization)
#
#  dense_4 (Dense)             (None, 1)                 892
#
# =================================================================
# Total params: 1,807,955
# Trainable params: 1,801,335
# Non-trainable params: 6,620
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 31)               124
#  ormalization)
#
#  dense (Dense)               (None, 991)               31712
#
#  batch_normalization_1 (Batc  (None, 991)              3964
#  hNormalization)
#
#  dense_1 (Dense)             (None, 536)               531712
#
#  batch_normalization_2 (Batc  (None, 536)              2144
#  hNormalization)
#
#  dense_2 (Dense)             (None, 861)               462357
#
#  batch_normalization_3 (Batc  (None, 861)              3444
#  hNormalization)
#
#  dense_3 (Dense)             (None, 891)               768042
#
#  batch_normalization_4 (Batc  (None, 891)              3564
#  hNormalization)
#
#  dense_4 (Dense)             (None, 1)                 892
#
# =================================================================
# Total params: 1,807,955
# Trainable params: 1,801,335
# Non-trainable params: 6,620
# _________________________________________________________________
# 0 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A40078FA0>
#    no activation attribute
# 1 <keras.layers.core.dense.Dense object at 0x0000017A40076D60>
#      <function relu at 0x0000017A362C6820>
# 2 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A400717F0>
#    no activation attribute
# 3 <keras.layers.core.dense.Dense object at 0x0000017A3FE37700>
#      <function selu at 0x0000017A362C6160>
# 4 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A400AFCA0>
#    no activation attribute
# 5 <keras.layers.core.dense.Dense object at 0x0000017A3FE37280>
#      <function relu at 0x0000017A362C6820>
# 6 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A3FE65730>
#    no activation attribute
# 7 <keras.layers.core.dense.Dense object at 0x0000017A3FE39D60>
#      <function relu at 0x0000017A362C6820>
# 8 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A3FE35640>
#    no activation attribute
# 9 <keras.layers.core.dense.Dense object at 0x0000017A3FE567F0>
#      <function selu at 0x0000017A362C6160>
# 9/9 [==============================] - 0s 6ms/step
# The coefficient of determination for Qc [W] Training Set using Neural Networks is 0.9514053786587819
# 3/3 [==============================] - 0s 4ms/step
# The coefficient of determination for Qc [W] Test Set using Neural Networks is 0.9071609545592232
# 9/9 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 3ms/step

# %%
Test_lite(X_train,y_train,'Qc [W]',Scaller)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 31)               124
#  ormalization)
#
#  dense (Dense)               (None, 991)               31712
#
#  batch_normalization_1 (Batc  (None, 991)              3964
#  hNormalization)
#
#  dense_1 (Dense)             (None, 536)               531712
#
#  batch_normalization_2 (Batc  (None, 536)              2144
#  hNormalization)
#
#  dense_2 (Dense)             (None, 861)               462357
#
#  batch_normalization_3 (Batc  (None, 861)              3444
#  hNormalization)
#
#  dense_3 (Dense)             (None, 891)               768042
#
#  batch_normalization_4 (Batc  (None, 891)              3564
#  hNormalization)
#
#  dense_4 (Dense)             (None, 1)                 892
#
# =================================================================
# Total params: 1,807,955
# Trainable params: 1,801,335
# Non-trainable params: 6,620
# _________________________________________________________________
# 0 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A3FD7FAF0>
#    no activation attribute
# 1 <keras.layers.core.dense.Dense object at 0x0000017A3FD28760>
#      <function relu at 0x0000017A362C6820>
# 2 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A420C2CD0>
#    no activation attribute
# 3 <keras.layers.core.dense.Dense object at 0x0000017A3FE24940>
#      <function selu at 0x0000017A362C6160>
# 4 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A3FD280D0>
#    no activation attribute
# 5 <keras.layers.core.dense.Dense object at 0x0000017A3FD407C0>
#      <function relu at 0x0000017A362C6820>
# 6 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A400C23A0>
#    no activation attribute
# 7 <keras.layers.core.dense.Dense object at 0x0000017A3FDE17C0>
#      <function relu at 0x0000017A362C6820>
# 8 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000017A3FE6DAC0>
#    no activation attribute
# 9 <keras.layers.core.dense.Dense object at 0x0000017A3FD0D460>
#      <function selu at 0x0000017A362C6160>
# INFO:tensorflow:Assets written to: C:\Users\Guilherme\AppData\Local\Temp\tmpn14slldr\assets
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 Test_lite(X_train,y_train,'Qc [W]',Scaller)
#
# Input In [14], in Test_lite(X_train, y_train, Obj, Scal)
#      24 Train_Lite = []
#      25 for i in range(np.shape(X_train)[0]):
# ---> 26     interpreter.set_tensor(input_index, Scaller.transform(X_train)[i].reshape(-1,1).T)
#      27     interpreter.invoke()
#      28     Train_Lite.append(interpreter.get_tensor(output_index)[0][0])
#
# File ~\Anaconda3\lib\site-packages\tensorflow\lite\python\interpreter.py:697, in Interpreter.set_tensor(self, tensor_index, value)
#     681 def set_tensor(self, tensor_index, value):
#     682   """Sets the value of the input tensor.
#     683
#     684   Note this copies data in `value`.
#    (...)
#     695     ValueError: If the interpreter could not set the tensor.
#     696   """
# --> 697   self._interpreter.SetTensor(tensor_index, value)
#
# ValueError: Cannot set tensor: Got value of type FLOAT64 but expected type FLOAT32 for input 0, name: serving_default_batch_normalization_input:0
